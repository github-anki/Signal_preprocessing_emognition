# %%
import pandas as pd
from utils.plotting import plot_experiment, plot_norm_experiment
from constants import *

# %%
df_empatica_acc = pd.read_csv('Data/03_synch_data/siedzaco/empatica_acc.csv')
df_empatica_ppg = pd.read_csv('Data/04_split_data/siedzaco/empatica_ppg.csv')

df_polar_acc = pd.read_csv('Data/03_synch_data/siedzaco/polar_acc.csv')
df_polar_ekg = pd.read_csv('Data/04_split_data/siedzaco/polar_ekg.csv')

df_samsung_acc = pd.read_csv('Data/03_synch_data/siedzaco/samsung_acc.csv')
df_samsung_ppg = pd.read_csv('Data/04_split_data/siedzaco/samsung_ppg.csv')

# %% [markdown]
# # 1st experiment - without move

# %%
plot_experiment(df_samsung_ppg, 'without_move')
plot_experiment(df_polar_ekg, 'without_move')
plot_experiment(df_empatica_ppg, 'without_move')

# %%
plot_norm_experiment(df_polar_ekg, df_empatica_ppg, df_samsung_ppg, 'without_move', SAMPLING_FREQ_POLAR, SAMPLING_FREQ_EMPATICA, SAMPLING_FREQ_SAMSUNG)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 2nd experiment - light

# %%
plot_experiment(df_samsung_ppg, 'light')
plot_experiment(df_polar_ekg, 'light')
plot_experiment(df_empatica_ppg, 'light')

# %%
plot_norm_experiment(df_polar_ekg, df_empatica_ppg, df_samsung_ppg, 'light', SAMPLING_FREQ_POLAR, SAMPLING_FREQ_EMPATICA, SAMPLING_FREQ_SAMSUNG)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 3rd experiment - hand move

# %%
plot_experiment(df_samsung_ppg, 'hand_move')
plot_experiment(df_polar_ekg, 'hand_move')
plot_experiment(df_empatica_ppg, 'hand_move')

# %%
plot_norm_experiment(df_polar_ekg, df_empatica_ppg, df_samsung_ppg, 'hand_move', SAMPLING_FREQ_POLAR, SAMPLING_FREQ_EMPATICA, SAMPLING_FREQ_SAMSUNG)

# %% [markdown]
# # 4th experiment - breathing

# %%
plot_experiment(df_samsung_ppg, 'breath')
plot_experiment(df_polar_ekg, 'breath')
plot_experiment(df_empatica_ppg, 'breath')

# %%
plot_norm_experiment(df_polar_ekg, df_empatica_ppg, df_samsung_ppg, 'breath', SAMPLING_FREQ_POLAR, SAMPLING_FREQ_EMPATICA, SAMPLING_FREQ_SAMSUNG)

# %%
df_empatica_acc = pd.read_csv('Data/03_synch_data/ruch/empatica_acc.csv')
df_empatica_ppg = pd.read_csv('Data/04_split_data/ruch/empatica_ppg.csv')

df_polar_acc = pd.read_csv('Data/03_synch_data/ruch/polar_acc.csv')
df_polar_ekg = pd.read_csv('Data/04_split_data/ruch/polar_ppg.csv')

df_samsung_acc = pd.read_csv('Data/03_synch_data/ruch/samsung_acc.csv')
df_samsung_ppg = pd.read_csv('Data/04_split_data/ruch/samsung_ppg.csv')

# %% [markdown]
# # 5th experiment - walking

# %%
plot_experiment(df_samsung_ppg, 'walking')
plot_experiment(df_polar_ekg, 'walking')
plot_experiment(df_empatica_ppg, 'walking')

# %%
plot_norm_experiment(df_polar_ekg, df_empatica_ppg, df_samsung_ppg, 'walking', SAMPLING_FREQ_POLAR, SAMPLING_FREQ_EMPATICA, SAMPLING_FREQ_SAMSUNG)

# %% [markdown]
# # 6th experiment - running

# %%
plot_experiment(df_samsung_ppg, 'running')
plot_experiment(df_polar_ekg, 'running')
plot_experiment(df_empatica_ppg, 'running')

# %%
plot_norm_experiment(df_polar_ekg, df_empatica_ppg, df_samsung_ppg, 'running', SAMPLING_FREQ_POLAR, SAMPLING_FREQ_EMPATICA, SAMPLING_FREQ_SAMSUNG)
